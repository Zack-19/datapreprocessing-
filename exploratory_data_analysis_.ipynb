# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load your dataset into a DataFrame (replace 'dataset.csv' with the actual path)
df = pd.read_csv('/content/drive/Shared drives/2023[PFE-1904] SAFA/Project phases/Dataset phase/preprocessing/symptoms - disease/n1 train.csv')
pd.set_option('display.max_colwidth', None)
# Display the first few rows of the dataset
print("First few rows of the dataset:")

print(df.head())
pd.set_option('display.max_colwidth', 50)
# Out:
# First few rows of the dataset:
#                output_text  \
# 0     cervical spondylosis
# 1                 impetigo
# 2  urinary tract infection
# 3                arthritis
# 4                   dengue
#
#                                                                                                                                                                                                                       input_text
# 0                                                           I've been having a lot of pain in my neck and back. I've also been having trouble with my balance and coordination. I've been coughing a lot and my limbs feel weak.
# 1                                                                                       I have a rash on my face that is getting worse. It is red, inflamed, and has blisters that are bleeding clear pus. It is really painful.
# ...

# %%
# Summary statistics of numerical columns
print("\nSummary statistics of numerical columns:")
print(df.describe())
# Out:
# Summary statistics of numerical columns:
#                  output_text  \
# count                    853
# unique                    22
# top     cervical spondylosis
# freq                      40
#
#                                                input_text
# count                                                 853
# unique                                                849
# top     I've been feeling really sick and tired. I've ...
# freq                                                    2

# %%
# Information about the dataset
print("\nInformation about the dataset:")
print(df.info())
# Out:
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   output_text  853 non-null    object
#  1   input_text   853 non-null    object
# dtypes: object(2)
# memory usage: 13.5+ KB
# None

# %%
# Check for missing values
print("\nMissing values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing values in the dataset:
# output_text    0
# input_text     0
# dtype: int64

# %%
# Check for duplicate rows
print("\nNumber of duplicate rows:")
print(df.duplicated().sum())
pd.set_option('display.max_colwidth', None)
print(df[df.duplicated()])
pd.set_option('display.max_colwidth', 50)
# Out:
# Number of duplicate rows:
# 4
#               output_text  \
# 682      bronchial asthma
# 696              jaundice
# 698  cervical spondylosis
# 832              jaundice
#
#                                                                                                                                                                               input_text
# 682  I've been having a hard time breathing lately. I feel like I can't get enough air, and my chest feels tight. I've also been coughing a lot, and I've been producing a lot of mucus.
# 696                                        I've been feeling really sick and tired. I've lost weight and have a fever. My urine is dark and my skin is yellow. I also have stomach pain.
# 698                 I have been having back pain, a cough that won't go away, and weakness in my arms and legs. My neck hurts and I have been dizzy and have trouble keeping my balance.
# ...

# %%
# Visualize data distributions
'''
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Numerical Column', bins=20, kde=True)
plt.title('Histogram of Numerical Column')
plt.xlabel('output_text')
plt.ylabel('Frequency')
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(10, 6))\nsns.histplot(data=df, x='Numerical Column', bins=20, kde=True)\nplt.title('Histogram of Numerical Column')\nplt.xlabel('output_text')\nplt.ylabel('Frequency')\nplt.show()\n"

# %%
# Visualize correlations between numerical columns
'''
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(10, 8))\nsns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)\nplt.title('Correlation Heatmap')\nplt.show()\n"

# %%
# Visualize categorical variables
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='output_text', order=df['output_text'].value_counts().index)
plt.title('Count of Categorical Column')
plt.xlabel('Categorical Column')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Box plot of numerical column by categorical column
'''
plt.figure(figsize=(10, 8))
sns.boxplot(data=df, x='categorical_column', y='numerical_column')
plt.title('Box Plot of Numerical Column by Categorical Column')
plt.xlabel('Categorical Column')
plt.ylabel('Numerical Column')
plt.xticks(rotation=45)
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(10, 8))\nsns.boxplot(data=df, x='categorical_column', y='numerical_column')\nplt.title('Box Plot of Numerical Column by Categorical Column')\nplt.xlabel('Categorical Column')\nplt.ylabel('Numerical Column')\nplt.xticks(rotation=45)\nplt.show()\n"
